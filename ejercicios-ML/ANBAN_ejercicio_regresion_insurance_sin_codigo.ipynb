# %% [markdown]
# # Ejercicio 1 — Modelo de Machine Learning de regresión
#
# ## Bootcamp ANBAN · Machine Learning básico
#
# En este notebook vas a construir un flujo completo de **Machine Learning supervisado para regresión**. La idea es practicar lo visto en clase, pero con un dataset distinto al utilizado en los notebooks de la sesión.
#
# El objetivo no es escribir muchísimo código, sino seguir con orden el flujo de trabajo completo:
#
# 1. cargar un dataset público,
# 2. entender qué queremos predecir,
# 3. hacer una preparación mínima del dato,
# 4. separar correctamente entrenamiento y test,
# 5. construir transformadores y modelos con `scikit-learn`,
# 6. comparar varios modelos de regresión,
# 7. interpretar los resultados con métricas adecuadas.
#
# > **Importante:** este notebook no contiene código resuelto. Cada celda de código vacía está pensada para que implementes tú el paso indicado justo encima.

# %% [markdown]
# ## Dataset propuesto
#
# Trabajaremos con el dataset público **Medical Cost Personal Dataset**.
#
# La tarea consiste en predecir el coste médico anual aproximado de una persona a partir de variables como edad, índice de masa corporal, número de hijos, si fuma o no, sexo y región.
#
# **URL de lectura del CSV:**
#
# `https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/insurance.csv`
#
# La variable objetivo será:
#
# - `charges`: coste médico anual.
#
# Variables disponibles esperadas:
#
# - `age`: edad.
# - `sex`: sexo.
# - `bmi`: índice de masa corporal.
# - `children`: número de hijos o personas dependientes.
# - `smoker`: si la persona fuma o no.
# - `region`: región.
# - `charges`: coste médico, que será la variable que queremos predecir.
#
# Este dataset es pequeño, manejable y tiene una mezcla útil de variables numéricas y categóricas, por lo que encaja muy bien para practicar preprocesado básico con `scikit-learn`.

# %% [markdown]
# ## Normas del ejercicio
#
# - No uses el dataset trabajado en el notebook de clase.
# - Mantén el nombre del dataframe principal como `df`.
# - Mantén la variable objetivo con el nombre `y`.
# - Mantén la matriz de variables predictoras con el nombre `X`.
# - Usa una separación de **80% entrenamiento** y **20% test**.
# - Usa `random_state=42` cuando haya aleatoriedad.
# - Evalúa todos los modelos sobre el mismo conjunto de test.
# - No compares modelos si han sido entrenados con datos distintos o preprocesados de forma distinta sin justificarlo.
# - No ajustes transformadores con todo el dataset antes de separar train/test. Recuerda el riesgo de *data leakage*.

# %% [markdown]
# ## Modelos mínimos a comparar
#
# Como mínimo, debes entrenar y evaluar estos modelos:
#
# 1. un modelo lineal de regresión,
# 2. KNN Regressor,
# 3. Support Vector Regressor,
# 4. Decision Tree Regressor,
# 5. Random Forest Regressor.
#
# También se recomienda incluir un modelo muy simple de referencia, por ejemplo un baseline que prediga siempre la media de la variable objetivo. Ese baseline sirve para saber si tus modelos están aprendiendo algo útil o solo parecen buenos porque no los estás comparando contra nada.

# %% [markdown]
# ## Celda 1 — Importación de librerías
#
# Importa las librerías necesarias para trabajar con datos, visualizar información y construir modelos con `scikit-learn`.
#
# Deberías importar, como mínimo, herramientas para:
#
# - manejar dataframes,
# - manejar operaciones numéricas,
# - crear gráficos básicos,
# - separar datos en entrenamiento y test,
# - construir pipelines,
# - transformar variables numéricas y categóricas,
# - entrenar los modelos de regresión pedidos,
# - calcular métricas de regresión.
#
# No hace falta importar todo `sklearn` entero. Importa solo las piezas que vayas a usar.
#
# **Qué deberías comprobar al terminar esta celda**
#
# La celda no debería mostrar ningún resultado especial. Simplemente debe ejecutarse sin errores.

# %% [markdown]
# ## Celda 2 — Carga del dataset
#
# Carga el CSV desde la URL indicada y guárdalo en una variable llamada `df`.
#
# Después muestra:
#
# - las primeras filas,
# - el tamaño del dataframe,
# - los nombres de las columnas.
#
# La idea de esta celda es comprobar que los datos se han leído correctamente antes de empezar a manipularlos.
#
# **Qué deberías comprobar al terminar esta celda**
#
# Deberías ver un dataframe con columnas como `age`, `sex`, `bmi`, `children`, `smoker`, `region` y `charges`. El dataset debería tener algo más de mil filas y pocas columnas.

# %% [markdown]
# ## Celda 3 — Primera inspección del dataset
#
# Explora la estructura general del dataframe.
#
# En esta celda debes comprobar:
#
# - el tipo de dato de cada columna,
# - si hay valores nulos,
# - si hay filas duplicadas,
# - un resumen estadístico de las columnas numéricas,
# - un resumen básico de las columnas categóricas.
#
# No limpies todavía nada. Primero observa.
#
# **Qué deberías comprobar al terminar esta celda**
#
# Deberías poder distinguir claramente qué columnas son numéricas y qué columnas son categóricas. También deberías saber si hay nulos o duplicados antes de decidir qué hacer con ellos.

# %% [markdown]
# ## Celda 4 — Definición del problema
#
# Escribe una pequeña comprobación para confirmar cuál será la variable objetivo.
#
# La variable objetivo será `charges`, porque queremos predecir un valor numérico continuo. Eso convierte este problema en un problema de **regresión supervisada**.
#
# En esta celda debes:
#
# - comprobar que `charges` existe en el dataframe,
# - observar sus valores principales,
# - revisar su distribución con algún resumen numérico y, si lo consideras útil, con un gráfico.
#
# **Qué deberías comprobar al terminar esta celda**
#
# Deberías confirmar que `charges` es una variable numérica continua. También es posible que observes que algunos costes son mucho más altos que otros.

# %% [markdown]
# ## Celda 5 — Limpieza mínima del dato
#
# Crea una versión limpia del dataframe. Puedes seguir usando el nombre `df` si sobrescribes el dataframe original, o crear una copia temporal y luego quedarte con ella.
#
# Debes hacer, como mínimo:
#
# - eliminar filas duplicadas si existen,
# - revisar los valores nulos,
# - decidir qué hacer con los nulos si aparecen.
#
# En este ejercicio se busca una limpieza sencilla. Si una columna tiene muy pocos nulos, puedes eliminar esas filas. Si no hay nulos, deja constancia en una salida de que el dataset no necesitaba imputación.
#
# **Qué deberías comprobar al terminar esta celda**
#
# Al terminar, deberías tener un dataframe preparado para separar `X` e `y`, sin duplicados y sin valores nulos problemáticos.

# %% [markdown]
# ## Celda 6 — Exploración visual mínima
#
# Realiza una exploración visual breve, no un EDA enorme.
#
# Como mínimo, genera visualizaciones o tablas para entender:
#
# - cómo se distribuye `charges`,
# - si `smoker` parece estar relacionado con `charges`,
# - si `bmi` o `age` parecen tener relación con `charges`,
# - si las variables categóricas tienen categorías razonables.
#
# Después de las gráficas, añade una celda Markdown breve con dos o tres observaciones.
#
# **Qué deberías comprobar al terminar esta celda**
#
# Deberías detectar alguna relación clara entre ciertas variables y el coste médico. No hace falta demostrar causalidad; solo observar patrones iniciales.

# %% [markdown]
# ### Observaciones de la exploración
#
# Escribe aquí, en 3-5 líneas, qué has observado. Por ejemplo, puedes comentar si hay variables que parecen más relacionadas con `charges`, si hay valores extremos o si alguna categoría parece especialmente importante.

# %% [markdown]
# ## Celda 7 — Separación entre variables predictoras y variable objetivo
#
# Crea las variables `X` e `y`.
#
# - `y` debe contener únicamente la columna `charges`.
# - `X` debe contener todas las columnas que usarás para predecir `charges`.
#
# En este ejercicio puedes usar todas las variables disponibles salvo la propia `charges`. Si decides quitar alguna variable, justifícalo en Markdown.
#
# Comprueba al final las dimensiones de `X` e `y`.
#
# **Qué deberías comprobar al terminar esta celda**
#
# `X` debería tener todas las variables de entrada y `y` debería ser una serie o vector con el coste médico. Ambas estructuras deben tener el mismo número de filas.

# %% [markdown]
# ## Celda 8 — Identificación de columnas numéricas y categóricas
#
# Crea dos listas de columnas:
#
# - una lista con las columnas numéricas,
# - otra lista con las columnas categóricas.
#
# Estas listas se usarán después para aplicar transformaciones distintas a cada tipo de variable.
#
# Recuerda que las variables numéricas se pueden escalar y las variables categóricas deben convertirse a formato numérico antes de entrar en la mayoría de modelos de `scikit-learn`.
#
# **Qué deberías comprobar al terminar esta celda**
#
# Deberías tener una lista con columnas como `age`, `bmi` y `children`, y otra con columnas como `sex`, `smoker` y `region`.

# %% [markdown]
# ## Celda 9 — Separación en train y test
#
# Divide `X` e `y` en entrenamiento y test.
#
# Usa:
#
# - 80% de datos para entrenamiento,
# - 20% de datos para test,
# - `random_state=42`.
#
# Guarda los cuatro conjuntos resultantes con nombres claros, por ejemplo los nombres habituales usados en clase.
#
# Esta separación debe hacerse antes de ajustar transformadores y modelos.
#
# **Qué deberías comprobar al terminar esta celda**
#
# Deberías obtener cuatro objetos: variables predictoras de entrenamiento, variables predictoras de test, objetivo de entrenamiento y objetivo de test. El conjunto de test debe contener aproximadamente el 20% de las filas.

# %% [markdown]
# ## Celda 10 — Construcción del preprocesador
#
# Construye un preprocesador con `scikit-learn` que haga dos cosas:
#
# - aplicar escalado estándar a las columnas numéricas,
# - aplicar codificación one-hot a las columnas categóricas.
#
# La herramienta más cómoda para esto es un transformador por columnas. El objetivo es que cada grupo de columnas reciba el tratamiento adecuado.
#
# No ajustes el preprocesador manualmente sobre todo el dataset. Lo ideal es integrarlo después dentro de cada `Pipeline` para que se ajuste solo con los datos de entrenamiento.
#
# **Qué deberías comprobar al terminar esta celda**
#
# Al final de la celda debes tener un objeto de preprocesado preparado, todavía no necesariamente ajustado. Este objeto será el primer paso de los pipelines de modelado.

# %% [markdown]
# ## Celda 11 — Baseline de regresión
#
# Entrena un modelo baseline muy sencillo.
#
# La idea es tener un punto de comparación mínimo. Por ejemplo, puedes usar un modelo que prediga siempre un valor central de `y_train`, como la media.
#
# Después evalúalo sobre test usando métricas de regresión.
#
# Métricas mínimas:
#
# - MAE,
# - RMSE,
# - R².
#
# Guarda los resultados en una estructura que puedas convertir más adelante en tabla.
#
# **Qué deberías comprobar al terminar esta celda**
#
# El baseline probablemente tendrá un rendimiento limitado. Si tus modelos serios no superan claramente este baseline, algo está fallando o el problema está mal planteado.

# %% [markdown]
# ## Celda 12 — Modelo lineal de regresión
#
# Construye un pipeline con dos pasos:
#
# 1. el preprocesador,
# 2. un modelo lineal de regresión.
#
# Entrena el pipeline con los datos de entrenamiento y predice sobre el conjunto de test.
#
# Calcula las mismas métricas que en el baseline: MAE, RMSE y R².
#
# Guarda los resultados con el nombre del modelo para poder compararlos después.
#
# **Qué deberías comprobar al terminar esta celda**
#
# Deberías obtener un primer modelo real. Es importante que uses exactamente el mismo test que en el baseline.

# %% [markdown]
# ## Celda 13 — KNN Regressor
#
# Construye un pipeline con el mismo preprocesador y un modelo KNN de regresión.
#
# Elige un valor inicial razonable para el número de vecinos. No hace falta optimizar todavía.
#
# Entrena, predice sobre test y calcula las mismas métricas.
#
# Recuerda que KNN es muy sensible a la escala, por eso el escalado de variables numéricas es especialmente importante.
#
# **Qué deberías comprobar al terminar esta celda**
#
# Deberías obtener otra fila de resultados. Compara mentalmente si mejora o empeora respecto al modelo lineal.

# %% [markdown]
# ## Celda 14 — Support Vector Regressor
#
# Construye un pipeline con el preprocesador y un modelo de tipo Support Vector Regressor.
#
# Puedes empezar con una configuración sencilla, sin hacer todavía una búsqueda de hiperparámetros.
#
# Entrena, predice y evalúa con las mismas métricas.
#
# Ten en cuenta que este modelo también suele depender bastante del escalado de las variables.
#
# **Qué deberías comprobar al terminar esta celda**
#
# Deberías añadir una nueva fila de resultados a tu tabla o lista de resultados.

# %% [markdown]
# ## Celda 15 — Decision Tree Regressor
#
# Construye un pipeline con el preprocesador y un árbol de decisión para regresión.
#
# Entrena el modelo, predice sobre test y calcula las métricas.
#
# Puedes usar una profundidad máxima limitada para evitar que el árbol memorice demasiado el entrenamiento. Si decides no limitarla, observa con cuidado si el resultado parece demasiado optimista o inestable.
#
# **Qué deberías comprobar al terminar esta celda**
#
# Deberías tener otro modelo comparable. Los árboles no necesitan escalado para funcionar, pero mantener el mismo pipeline simplifica la comparación y permite codificar variables categóricas de forma consistente.

# %% [markdown]
# ## Celda 16 — Random Forest Regressor
#
# Construye un pipeline con el preprocesador y un Random Forest de regresión.
#
# Usa un número razonable de árboles y fija `random_state=42`.
#
# Entrena, predice y evalúa igual que en los modelos anteriores.
#
# Este modelo suele ser un buen candidato cuando hay relaciones no lineales entre las variables y la variable objetivo.
#
# **Qué deberías comprobar al terminar esta celda**
#
# Deberías obtener la última fila de resultados de la comparación principal.

# %% [markdown]
# ## Celda 17 — Tabla comparativa de modelos
#
# Construye una tabla final con todos los resultados.
#
# La tabla debe tener, como mínimo, estas columnas:
#
# - nombre del modelo,
# - MAE en test,
# - RMSE en test,
# - R² en test.
#
# Ordena la tabla con un criterio razonable. Por ejemplo, puedes ordenar por menor RMSE o por mayor R².
#
# Asegúrate de que todos los modelos se han evaluado sobre el mismo conjunto de test.
#
# **Qué deberías comprobar al terminar esta celda**
#
# Deberías ver claramente qué modelo funciona mejor según cada métrica. Puede ocurrir que no todas las métricas ordenen los modelos exactamente igual.

# %% [markdown]
# ## Celda 18 — Visualización de predicciones
#
# Elige el mejor modelo según tu criterio principal y genera una visualización que compare valores reales frente a valores predichos.
#
# La gráfica debe ayudarte a responder:
#
# - si el modelo predice bien los valores bajos,
# - si falla más en valores altos,
# - si hay errores muy grandes,
# - si las predicciones siguen una tendencia razonable.
#
# No hace falta que la gráfica sea sofisticada. Lo importante es que sea interpretable.
#
# **Qué deberías comprobar al terminar esta celda**
#
# Si el modelo fuese perfecto, los puntos estarían muy cerca de una diagonal imaginaria donde valor real y valor predicho coinciden. En la práctica habrá desviaciones.

# %% [markdown]
# ## Celda 19 — Análisis de errores
#
# Crea una pequeña tabla o dataframe con, al menos:
#
# - valor real,
# - valor predicho,
# - error absoluto.
#
# Ordena la tabla por los errores más altos y observa algunos casos donde el modelo falla más.
#
# El objetivo es interpretar el error, no solo mirar una métrica media.
#
# **Qué deberías comprobar al terminar esta celda**
#
# Deberías poder identificar si los mayores errores se concentran en personas con costes médicos muy altos o en algún perfil concreto.

# %% [markdown]
# ## Celda 20 — Discusión final
#
# Escribe una conclusión breve, entre 8 y 12 líneas, respondiendo a estas preguntas:
#
# 1. ¿Qué modelo ha funcionado mejor según RMSE?
# 2. ¿Qué modelo ha funcionado mejor según R²?
# 3. ¿El mejor modelo supera claramente al baseline?
# 4. ¿Qué variables crees que han sido más importantes para predecir `charges`?
# 5. ¿Crees que el modelo falla más en algunos perfiles concretos?
# 6. ¿Qué harías como siguiente mejora si tuvieras más tiempo?
#
# No busques una respuesta perfecta. Lo importante es que conectes métricas, gráficas y criterio.

# %% [markdown]
# ## Extra opcional — Búsqueda sencilla de hiperparámetros
#
# Si terminas pronto, elige **uno** de los modelos anteriores y prueba una pequeña búsqueda de hiperparámetros.
#
# Puedes hacerlo, por ejemplo, con KNN, SVR, Decision Tree o Random Forest.
#
# La búsqueda debe ser pequeña. El objetivo no es encontrar el mejor modelo posible del mundo, sino practicar la idea de que algunos modelos dependen mucho de sus hiperparámetros.
#
# Después compara:
#
# - modelo original,
# - modelo ajustado,
# - mejora o empeoramiento en test.

# %% [markdown]
# ## Checklist antes de entregar
#
# Antes de entregar, revisa que tu notebook cumple lo siguiente:
#
# - el notebook se ejecuta de arriba abajo sin errores,
# - el dataset usado es el indicado en este ejercicio,
# - existe una separación clara entre `X` e `y`,
# - hay train/test split,
# - las variables categóricas se transforman correctamente,
# - las variables numéricas se escalan cuando corresponde,
# - se comparan al menos cinco modelos de regresión,
# - se usan MAE, RMSE y R²,
# - hay una tabla comparativa final,
# - hay una conclusión escrita con criterio.
